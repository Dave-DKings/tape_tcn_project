# %% [markdown]
# # Experiment Templates and Checklists
#
# Use this notebook as the standard template for new runs and research logging.

# %% [markdown]
# ## 1) Pre-Run Checklist
#
# - confirm active config values,
# - confirm variant (`TCN` / `TCN + Attention`),
# - confirm seed and timesteps,
# - confirm output directory,
# - confirm train/test date boundaries.

# %% [markdown]
# ## 2) Run Record Template
#
# - Run ID:
# - Date:
# - Variant:
# - sequence_length:
# - tcn_filters:
# - tcn_kernel_size:
# - tcn_dilations:
# - dirichlet activation:
# - timesteps:
# - ppo update interval:
# - turnover curriculum:
# - drawdown settings:
# - notes:

# %% [markdown]
# ## 3) Post-Run Checklist
#
# - metadata JSON saved,
# - episode and summary CSV saved,
# - checkpoints saved,
# - evaluation completed,
# - deterministic and stochastic outputs captured,
# - no date-split mismatch.

# %% [markdown]
# ## 4) Placeholder Tables for Write-Up
#
# ### Variant Results (Placeholder)
#
# | Variant | Timesteps | Test Sharpe | Test MDD | Turnover | Notes |
# |---|---:|---:|---:|---:|---|
# | TCN | TBD | TBD | TBD | TBD | pending |
# | TCN + Attention | TBD | TBD | TBD | TBD | pending |
#
# ### Diagnostics (Placeholder)
#
# | Run ID | Mean TAPE Score | Mean Drawdown Lambda | Max Drawdown | Turnover |
# |---|---:|---:|---:|---:|
# | TBD | TBD | TBD | TBD | TBD |

# %% [markdown]
# ## 5) Change Log
#
# - YYYY-MM-DD: <change>
# - YYYY-MM-DD: <change>
# - YYYY-MM-DD: <change>
