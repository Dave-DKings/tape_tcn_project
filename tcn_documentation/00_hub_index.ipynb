# %% [markdown]
# # TCN Documentation Hub
#
# This is the fresh documentation hub for the current TCN project implementation.
#
# Purpose:
#
# - keep write-up content synchronized with code,
# - explain concepts in both plain language and math,
# - log progress in one structured place as experiments evolve.

# %% [markdown]
# ## Documentation Map
#
# 1. `01_reward_system_full.ipynb`
# 2. `02_variables_and_tickers_reference.ipynb`
# 3. `03_tcn_architectures_and_variants.ipynb`
# 4. `04_data_pipeline_and_normalization.ipynb`
# 5. `05_training_evaluation_logging.ipynb`
# 6. `06_experiment_templates_and_checklists.ipynb`
# 7. `07_glossary_and_formula_sheet.ipynb`
# 8. `08_actuarial_features_reference.ipynb`
# 9. `09_state_of_the_art_research_plan.ipynb`
# 10. `10_research_paper_outline.ipynb`
# 11. `11_manuscript_claims_registry.ipynb`

# %% [markdown]
# ## Ground-Truth Code Files
#
# - `src/config.py`
# - `src/environment_tape_rl.py`
# - `src/agents/actor_critic_tf.py`
# - `src/agents/ppo_agent_tf.py`
# - `src/data_utils.py`
# - `src/notebook_helpers/tcn_phase1.py`
# - `src/reward_utils.py`
# - `tcn_architecture_analysis.ipynb` (primary execution notebook)

# %% [markdown]
# ## Update Rule
#
# When implementation changes:
#
# 1. update code,
# 2. update affected notebook(s) here,
# 3. append an entry in the change log template notebook.

# %%
from src.config import PHASE1_CONFIG, ASSET_TICKERS
print('Assets:', ASSET_TICKERS)
print('Architecture:', PHASE1_CONFIG['agent_params']['actor_critic_type'])
print('TCN settings:', PHASE1_CONFIG['agent_params']['tcn_filters'], PHASE1_CONFIG['agent_params']['tcn_kernel_size'], PHASE1_CONFIG['agent_params']['tcn_dilations'])
